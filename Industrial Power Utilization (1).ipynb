# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("C:\\Users\\soumy\\Downloads\\ML Projects\\Industrial\\Dataset\\Training_data.xlsx")
df
# Out:
#        Unnamed: 0                date  Energy_Consumption  LaRP  LeRP   LaPF  \
# 0               0 2018-01-01 00:15:00                3.21  2.96  0.00  73.21
# 1               1 2018-01-01 00:30:00                3.95  4.46  0.00  66.78
# 2               2 2018-01-01 00:45:00                3.23  3.28  0.00  70.27
# 3               3 2018-01-01 01:00:00                3.33  3.56  0.00  68.10
# 4               4 2018-01-01 01:15:00                3.79  4.49  0.00  64.72
# ...           ...                 ...                 ...   ...   ...    ...
# 32845          86 2018-12-31 22:45:00                3.84  4.56  0.00  64.37
# 32846          87 2018-12-31 23:15:00                3.81  3.76  0.00  70.71
# 32847          88 2018-12-31 23:30:00                3.82  3.16  0.07  76.64
# 32848          89 2018-12-31 23:45:00                3.85  3.07  0.13  77.72
# 32849          90 2018-12-31 00:00:00                3.65  3.03  0.08  77.23
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32850 entries, 0 to 32849
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    32850 non-null  int64
#  1   date                          32850 non-null  datetime64[ns]
#  2   Energy_Consumption            32850 non-null  float64
#  3   LaRP                          32850 non-null  float64
#  4   LeRP                          32850 non-null  float64
#  5   LaPF                          32850 non-null  float64
#  6   LePF                          32850 non-null  float64
#  7   Duty                          32850 non-null  object
#  8   Emissions_Air_Quality_Metric  32850 non-null  int64
#  9   Date                          32850 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(1)
# memory usage: 2.5+ MB

# %%
sns.kdeplot(df['Energy_Consumption'])
# Out:
# <Axes: xlabel='Energy_Consumption', ylabel='Density'>

# %%
sns.stripplot(df['Energy_Consumption'])
# Out:
# <Axes: ylabel='Energy_Consumption'>

# %%
sns.boxplot(df['Energy_Consumption'])
# Out:
# <Axes: >

# %%
Q1 = df['Energy_Consumption'].quantile(0.25)
Q3 = df['Energy_Consumption'].quantile(0.75)
IQR = Q3 - Q1
HF =  Q3 + 1.5 * IQR

# %%
print(Q1,Q3,IQR,HF)
# Out:
# 3.22 51.2 47.980000000000004 123.17

# %%
df[df['Energy_Consumption']>123.17].shape[0]
# Out:
# 302

# %%
(df[df['Energy_Consumption']>123.17].shape[0]/df.shape[0])*100
# Out:
# 0.919330289193303

# %%
sns.boxplot(df['Emissions_Air_Quality_Metric'])
# Out:
# <Axes: >

# %%
sns.distplot(df['Emissions_Air_Quality_Metric'])
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_17780\3798783138.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Emissions_Air_Quality_Metric'])
# <Axes: xlabel='Emissions_Air_Quality_Metric', ylabel='Density'>

# %%
Q1 = df['Emissions_Air_Quality_Metric'].quantile(0.25)
Q3 = df['Emissions_Air_Quality_Metric'].quantile(0.75)
IQR = Q3 - Q1
HF =  Q3 + 1.5 * IQR

# %%
print(Q1,Q3,IQR,HF)
# Out:
# 99.0 232.0 133.0 431.5

# %%
df[df['Emissions_Air_Quality_Metric']>431.5].shape[0]
# Out:
# 403

# %%
df[df['Emissions_Air_Quality_Metric']>500].shape[0]
# Out:
# 24

# %% [markdown]
# ## Enegy consumption

# %%
sns.scatterplot(data=df,x='Emissions_Air_Quality_Metric',y='Energy_Consumption')
# Out:
# <Axes: xlabel='Emissions_Air_Quality_Metric', ylabel='Energy_Consumption'>

# %%
df[['Emissions_Air_Quality_Metric','Energy_Consumption']].corr()
# Out:
#                               Emissions_Air_Quality_Metric  Energy_Consumption
# Emissions_Air_Quality_Metric                      1.000000            0.987338
# Energy_Consumption                                0.987338            1.000000

# %% [markdown]
# ## LaRP

# %%
sns.scatterplot(data=df,x='Emissions_Air_Quality_Metric',y='LaRP')
# Out:
# <Axes: xlabel='Emissions_Air_Quality_Metric', ylabel='LaRP'>

# %%
sns.scatterplot(data=df,x='Energy_Consumption',y='LaRP')
# Out:
# <Axes: xlabel='Energy_Consumption', ylabel='LaRP'>

# %% [markdown]
# ## LeRP

# %%
sns.scatterplot(data=df,x='Emissions_Air_Quality_Metric',y='LeRP')
# Out:
# <Axes: xlabel='Emissions_Air_Quality_Metric', ylabel='LeRP'>

# %%
sns.scatterplot(data=df,x='Energy_Consumption',y='LeRP')
# Out:
# <Axes: xlabel='Energy_Consumption', ylabel='LeRP'>

# %% [markdown]
# ## LaRP vs LeRP

# %%
sns.scatterplot(data=df,x='LaRP',y='LeRP')
# Out:
# <Axes: xlabel='LaRP', ylabel='LeRP'>

# %%
## LaPF vs LaRP

# %%
sns.scatterplot(data=df,x='LaRP',y='LaPF')
# Out:
# <Axes: xlabel='LaRP', ylabel='LaPF'>

# %% [markdown]
# ## LaPF

# %%
sns.scatterplot(data=df,x='LeRP',y='LePF')
# Out:
# <Axes: xlabel='LeRP', ylabel='LePF'>

# %% [markdown]
# ## Correlation

# %%
df[['LaPF','LePF','LeRP','LaRP','Energy_Consumption']].corr()
# Out:
#                         LaPF      LePF      LeRP      LaRP  Energy_Consumption
# LaPF                1.000000 -0.519332  0.526259  0.145180            0.387515
# LePF               -0.519332  1.000000 -0.943987  0.406997            0.352853
# LeRP                0.526259 -0.943987  1.000000 -0.404410           -0.324078
# LaRP                0.145180  0.406997 -0.404410  1.000000            0.895440
# Energy_Consumption  0.387515  0.352853 -0.324078  0.895440            1.000000

# %% [markdown]
# ## Adding features true power PowerFactor = True power/(True Power + Reactive Power)

# %%
df['LaPF'] = df['LaPF']  / 100
df['LaTP'] = df['LaRP'] * np.sqrt((1 - df['LaPF']**2) / df['LaPF']**2)
df
# Out:
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#        Unnamed: 0                date  Energy_Consumption  LaRP  LeRP    LaPF  \
# 0               0 2018-01-01 00:15:00                3.21  2.96  0.00  0.7321
# 1               1 2018-01-01 00:30:00                3.95  4.46  0.00  0.6678
# 2               2 2018-01-01 00:45:00                3.23  3.28  0.00  0.7027
# 3               3 2018-01-01 01:00:00                3.33  3.56  0.00  0.6810
# 4               4 2018-01-01 01:15:00                3.79  4.49  0.00  0.6472
# ...           ...                 ...                 ...   ...   ...     ...
# 32845          86 2018-12-31 22:45:00                3.84  4.56  0.00  0.6437
# 32846          87 2018-12-31 23:15:00                3.81  3.76  0.00  0.7071
# ...

# %%
df['LePF'] = df['LePF']  / 100
df['LeTP'] = df['LeRP'] * np.sqrt((1 - df['LePF']**2) / df['LePF']**2)
df
# Out:
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#        Unnamed: 0                date  Energy_Consumption  LaRP  LeRP    LaPF  \
# 0               0 2018-01-01 00:15:00                3.21  2.96  0.00  0.7321
# 1               1 2018-01-01 00:30:00                3.95  4.46  0.00  0.6678
# 2               2 2018-01-01 00:45:00                3.23  3.28  0.00  0.7027
# 3               3 2018-01-01 01:00:00                3.33  3.56  0.00  0.6810
# 4               4 2018-01-01 01:15:00                3.79  4.49  0.00  0.6472
# ...           ...                 ...                 ...   ...   ...     ...
# 32845          86 2018-12-31 22:45:00                3.84  4.56  0.00  0.6437
# 32846          87 2018-12-31 23:15:00                3.81  3.76  0.00  0.7071
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32850 entries, 0 to 32849
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    32850 non-null  int64
#  1   date                          32850 non-null  datetime64[ns]
#  2   Energy_Consumption            32850 non-null  float64
#  3   LaRP                          32850 non-null  float64
#  4   LeRP                          32850 non-null  float64
#  5   LaPF                          32850 non-null  float64
#  6   LePF                          32850 non-null  float64
#  7   Duty                          32850 non-null  object
#  8   Emissions_Air_Quality_Metric  32850 non-null  int64
#  9   Date                          32850 non-null  datetime64[ns]
#  10  LaTP                          32834 non-null  float64
#  11  LeTP                          32814 non-null  float64
# ...

# %%
sns.scatterplot(data=df,x='Energy_Consumption',y='LaTP')
# Out:
# <Axes: xlabel='Energy_Consumption', ylabel='LaTP'>

# %%
df.groupby('Duty')['Energy_Consumption'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Duty'>

# %%
columns_to_plot=['LaRP','LeRP','LaPF','LePF','LaTP','LeTP']
for column in columns_to_plot:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x=df['Emissions_Air_Quality_Metric'], y=df[column])
    plt.xlabel('Emissions_Air_Quality_Metric')
    plt.ylabel(column.capitalize())
    plt.title(f'{column.capitalize()} over Time')
    plt.grid(True)
    plt.xticks(rotation=45)  # Rotate datetime labels for better readability
    plt.tight_layout()
    plt.show()

# %%
columns_to_plot=['LaRP','LeRP','LaPF','LePF','LaTP','LeTP']
for column in columns_to_plot:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x=df['Energy_Consumption'], y=df[column])
    plt.xlabel('Energy_Consumption')
    plt.ylabel(column.capitalize())
    plt.title(f'{column.capitalize()} over Time')
    plt.grid(True)
    plt.xticks(rotation=45)  # Rotate datetime labels for better readability
    plt.tight_layout()
    plt.show()

# %%
correlation_matrix1 = df[['Energy_Consumption','LaRP','LaPF','LaTP','LeRP','LePF','LeTP']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix1, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
value_counts = df['Emissions_Air_Quality_Metric'].value_counts().sort_values()

# Plot the sorted value counts
value_counts.plot(kind='bar')
plt.xlabel('Emissions Air Quality Metric')
plt.ylabel('Counts')
plt.title('Counts of Emissions Air Quality Metric')
plt.show()

# %%
columns_to_plot=['LaRP','LaPF','LaTP','LeRP','LePF','LeTP']
for column in columns_to_plot:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x=df['LaTP'], y=df[column])
    plt.xlabel('LaTP')
    plt.ylabel(column.capitalize())
    plt.title(f'{column.capitalize()} over Time')
    plt.grid(True)
    plt.xticks(rotation=45)  # Rotate datetime labels for better readability
    plt.tight_layout()
    plt.show()

# %%
df[['LaRP','LeRP','LaPF','LePF','LaTP','LeTP']].corr()
# Out:
#           LaRP      LeRP      LaPF      LePF      LaTP      LeTP
# LaRP  1.000000 -0.404410  0.145180  0.406997  0.888253 -0.353271
# LeRP -0.404410  1.000000  0.526259 -0.943987 -0.455226  0.945163
# LaPF  0.145180  0.526259  1.000000 -0.519332 -0.193814  0.452943
# LePF  0.406997 -0.943987 -0.519332  1.000000  0.453200 -0.913017
# LaTP  0.888253 -0.455226 -0.193814  0.453200  1.000000 -0.393062
# LeTP -0.353271  0.945163  0.452943 -0.913017 -0.393062  1.000000

# %%
df['LaAP'] = df['LaTP']/df['LaPF']

# %%
df['LeAP'] = df['LeTP']/df['LePF']

# %%
df
# Out:
#        Unnamed: 0                date  Energy_Consumption  LaRP  LeRP    LaPF  \
# 0               0 2018-01-01 00:15:00                3.21  2.96  0.00  0.7321
# 1               1 2018-01-01 00:30:00                3.95  4.46  0.00  0.6678
# 2               2 2018-01-01 00:45:00                3.23  3.28  0.00  0.7027
# 3               3 2018-01-01 01:00:00                3.33  3.56  0.00  0.6810
# 4               4 2018-01-01 01:15:00                3.79  4.49  0.00  0.6472
# ...           ...                 ...                 ...   ...   ...     ...
# 32845          86 2018-12-31 22:45:00                3.84  4.56  0.00  0.6437
# 32846          87 2018-12-31 23:15:00                3.81  3.76  0.00  0.7071
# 32847          88 2018-12-31 23:30:00                3.82  3.16  0.07  0.7664
# 32848          89 2018-12-31 23:45:00                3.85  3.07  0.13  0.7772
# 32849          90 2018-12-31 00:00:00                3.65  3.03  0.08  0.7723
#
# ...

# %%
correlation_matrix1 = df[['Energy_Consumption','LaRP','LaPF','LaTP','LaAP','LeRP','LePF','LeTP','LeAP']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix1, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32850 entries, 0 to 32849
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    32850 non-null  int64
#  1   date                          32850 non-null  datetime64[ns]
#  2   Energy_Consumption            32850 non-null  float64
#  3   LaRP                          32850 non-null  float64
#  4   LeRP                          32850 non-null  float64
#  5   LaPF                          32850 non-null  float64
#  6   LePF                          32850 non-null  float64
#  7   Duty                          32850 non-null  object
#  8   Emissions_Air_Quality_Metric  32850 non-null  int64
#  9   Date                          32850 non-null  datetime64[ns]
#  10  LaTP                          32834 non-null  float64
#  11  LeTP                          32814 non-null  float64
# ...

# %%
columns_to_plot=['LaAP','LaTP','LeAP','LeTP']
for column in columns_to_plot:
    plt.figure(figsize=(10, 5))
    sns.distplot(df[column])
    plt.xlabel(column.capitalize())
    plt.title(f'{column.capitalize()} over Time')
    plt.grid(True)
    plt.xticks(rotation=45)  # Rotate datetime labels for better readability
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_17780\2552590331.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\soumy\AppData\Local\Temp\ipykernel_17780\2552590331.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'Energy_Consumption', 'LaRP', 'LeRP', 'LaPF',
#        'LePF', 'Duty', 'Emissions_Air_Quality_Metric', 'Date', 'LaTP', 'LeTP',
#        'LaAP', 'LeAP'],
#       dtype='object')

# %%
columns_to_plot=['Energy_Consumption', 'LaRP', 'LeRP', 'LaPF','LePF', 'Emissions_Air_Quality_Metric', 'LaTP', 'LeTP','LeAP', 'LaAP']
for column in columns_to_plot:
    plt.figure(figsize=(10, 5))
    sns.boxplot(df[column])
    plt.xlabel(column.capitalize())
    plt.title(f'{column.capitalize()} over Time')
    plt.grid(True)
    plt.xticks(rotation=45)  # Rotate datetime labels for better readability
    plt.tight_layout()
    plt.show()

# %%
Q1 = df['Energy_Consumption'].quantile(0.25)
Q3 = df['Energy_Consumption'].quantile(0.75)
IQR = Q3 - Q1
HF =  Q3 + 1.5 * IQR

# %%
print(Q1,Q3,IQR,HF)
# Out:
# 3.22 51.2 47.980000000000004 123.17

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'Energy_Consumption', 'LaRP', 'LeRP', 'LaPF',
#        'LePF', 'Duty', 'Emissions_Air_Quality_Metric', 'Date', 'LaTP', 'LeTP',
#        'LaAP', 'LeAP'],
#       dtype='object')

# %%
list2 =['Energy_Consumption', 'LaRP', 'LeRP', 'LaPF','LePF', 'Emissions_Air_Quality_Metric','LaTP', 'LeTP','LaAP', 'LeAP']
for i in list2:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    HF =  Q3 + 1.5 * IQR
    outliers = df[df[i]>HF].shape[0]
    max=df[i].max()
    print(i,HF,outliers,max)
# Out:
# Energy_Consumption 123.17 302 157.2
# LaRP 52.910000000000004 1009 96.89
# LeRP 5.050000000000001 7330 27.77
# LaPF 1.52635 0 1.0001
# LePF 1.00435 0 1.0001
# Emissions_Air_Quality_Metric 431.5 403 562
# LaTP 28.076588276834624 1595 77.34427547909118
# LeTP 0.2962498929428723 7893 211.7259326623224
# LaAP 45.411874820702955 674 116.67563053113768
# LeAP 0.29673952272030335 7893 1695.1456214143368

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'Energy_Consumption', 'LaRP', 'LeRP', 'LaPF',
#        'LePF', 'Duty', 'Emissions_Air_Quality_Metric', 'Date', 'LaTP', 'LeTP',
#        'LaAP', 'LeAP'],
#       dtype='object')

# %%
df=df.drop(columns=['Unnamed: 0','date','Date'])
df
# Out:
#        Energy_Consumption  LaRP  LeRP    LaPF    LePF Duty  \
# 0                    3.21  2.96  0.00  0.7321  1.0000  Low
# 1                    3.95  4.46  0.00  0.6678  1.0000  Low
# 2                    3.23  3.28  0.00  0.7027  1.0000  Low
# 3                    3.33  3.56  0.00  0.6810  1.0000  Low
# 4                    3.79  4.49  0.00  0.6472  1.0000  Low
# ...                   ...   ...   ...     ...     ...  ...
# 32845                3.84  4.56  0.00  0.6437  1.0000  Low
# 32846                3.81  3.76  0.00  0.7071  1.0000  Low
# 32847                3.82  3.16  0.07  0.7664  0.9999  Low
# 32848                3.85  3.07  0.13  0.7772  0.9996  Low
# 32849                3.65  3.03  0.08  0.7723  0.9999  Low
#
#        Emissions_Air_Quality_Metric      LaTP      LeTP      LaAP      LeAP
# 0                               105  2.754192  0.000000  3.762043  0.000000
# 1                               101  4.971189  0.000000  7.444128  0.000000
# ...

# %%
df['Duty'].unique()
# Out:
# array(['Low', 'Average', 'Major'], dtype=object)

# %%
df['Duty'] = df['Duty'].replace({'Low':0,'Average':1,'Major':2})
df
# Out:
#        Energy_Consumption  LaRP  LeRP    LaPF    LePF  Duty  \
# 0                    3.21  2.96  0.00  0.7321  1.0000     0
# 1                    3.95  4.46  0.00  0.6678  1.0000     0
# 2                    3.23  3.28  0.00  0.7027  1.0000     0
# 3                    3.33  3.56  0.00  0.6810  1.0000     0
# 4                    3.79  4.49  0.00  0.6472  1.0000     0
# ...                   ...   ...   ...     ...     ...   ...
# 32845                3.84  4.56  0.00  0.6437  1.0000     0
# 32846                3.81  3.76  0.00  0.7071  1.0000     0
# 32847                3.82  3.16  0.07  0.7664  0.9999     0
# 32848                3.85  3.07  0.13  0.7772  0.9996     0
# 32849                3.65  3.03  0.08  0.7723  0.9999     0
#
#        Emissions_Air_Quality_Metric      LaTP      LeTP      LaAP      LeAP
# 0                               105  2.754192  0.000000  3.762043  0.000000
# 1                               101  4.971189  0.000000  7.444128  0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32850 entries, 0 to 32849
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Energy_Consumption            32850 non-null  float64
#  1   LaRP                          32850 non-null  float64
#  2   LeRP                          32850 non-null  float64
#  3   LaPF                          32850 non-null  float64
#  4   LePF                          32850 non-null  float64
#  5   Duty                          32850 non-null  int64
#  6   Emissions_Air_Quality_Metric  32850 non-null  int64
#  7   LaTP                          32834 non-null  float64
#  8   LeTP                          32814 non-null  float64
#  9   LaAP                          32834 non-null  float64
#  10  LeAP                          32814 non-null  float64
# dtypes: float64(9), int64(2)
# memory usage: 2.8 MB

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
df_imputed = imputer.fit_transform(df[['LaTP','LaAP','LeTP','LeAP']])
df_imputed = pd.DataFrame(df_imputed, columns=['LaTP','LaAP','LeTP','LeAP'])

# %%
df_imputed
# Out:
#            LaTP      LaAP      LeTP      LeAP
# 0      2.754192  3.762043  0.000000  0.000000
# 1      4.971189  7.444128  0.000000  0.000000
# 2      3.321012  4.726073  0.000000  0.000000
# 3      3.828090  5.621277  0.000000  0.000000
# 4      5.288656  8.171594  0.000000  0.000000
# ...         ...       ...       ...       ...
# 32845  5.421264  8.422034  0.000000  0.000000
# 32846  3.760072  5.317596  0.000000  0.000000
# 32847  2.648577  3.455867  0.000990  0.000990
# 32848  2.485601  3.198148  0.003678  0.003680
# 32849  2.492337  3.227161  0.001131  0.001132
#
# [32850 rows x 4 columns]

# %%
df['LaTP'] = df_imputed['LaTP']
df['LaAP'] = df_imputed['LaAP']
df['LeTP'] = df_imputed['LeTP']
df['LeAP'] = df_imputed['LeAP']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32850 entries, 0 to 32849
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Energy_Consumption            32850 non-null  float64
#  1   LaRP                          32850 non-null  float64
#  2   LeRP                          32850 non-null  float64
#  3   LaPF                          32850 non-null  float64
#  4   LePF                          32850 non-null  float64
#  5   Duty                          32850 non-null  int64
#  6   Emissions_Air_Quality_Metric  32850 non-null  int64
#  7   LaTP                          32850 non-null  float64
#  8   LeTP                          32850 non-null  float64
#  9   LaAP                          32850 non-null  float64
#  10  LeAP                          32850 non-null  float64
# dtypes: float64(9), int64(2)
# memory usage: 2.8 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
X = df.drop(columns=['Energy_Consumption'])
y = df['Energy_Consumption']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=30)

# %%
# Initialize and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on the test set
y_pred = model.predict(X_test)

# %%
# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
adjusted_r2 = 1 - (1-r2) * (len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

# %%
# Print the results
print("Linear Regression Performance:")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R2 Score: {r2:.4f}")
print(f"Adjusted R2 Score: {adjusted_r2:.4f}")
# Out:
# Linear Regression Performance:
# Mean Squared Error (MSE): 13.9427
# Root Mean Squared Error (RMSE): 3.7340
# Mean Absolute Error (MAE): 2.4492
# R2 Score: 0.9875
# Adjusted R2 Score: 0.9875

# %%
df['Energy_Consumption'].mean()
# Out:
# 27.333205479452054

# %%
# Plotting feature importance
importance = model.coef_
features = X.columns

plt.figure(figsize=(10, 8))
plt.barh(features, importance)
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importance')
plt.show()

# %%
from sklearn.linear_model import Lasso

# Initialize the Lasso Regression model
lasso_model = Lasso(alpha=0.1)

# Train the model on the training data
lasso_model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = lasso_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error
mae = mean_absolute_error(y_test, y_pred)  # Mean Absolute Error
r2 = r2_score(y_test, y_pred)  # R-squared
n = len(y_test)  # Number of samples in the test set
p = X_test.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))  # Adjusted R-squared

# Print the evaluation metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R2: {r2}')
print(f'Adjusted R2: {adjusted_r2}')
# Out:
# MSE: 16.193917349137656
# RMSE: 4.024166665178973
# MAE: 2.525907142971757
# R2: 0.9855352332291498
# Adjusted R2: 0.985505815358963

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'alpha': [0.01, 0.1, 1, 10, 100],  # Regularization strength
    'max_iter': [1000, 5000, 10000],  # Maximum number of iterations
    'tol': [0.0001, 0.001, 0.01]  # Tolerance for optimization
}

# Perform Grid Search with cross-validation
grid_search = GridSearchCV(lasso_model, param_grid, cv=5, scoring='neg_mean_squared_error') #jis naam se model initialize kiya h wohi pass karna h 
grid_search.fit(X_train, y_train)

# Print the best parameters found by Grid Search
print(f'Best parameters: {grid_search.best_params_}')

# Train the Lasso model with the best parameters
best_lasso = grid_search.best_estimator_
best_lasso.fit(X_train, y_train)

# Make predictions on the test data
y_pred = best_lasso.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error
mae = mean_absolute_error(y_test, y_pred)  # Mean Absolute Error
r2 = r2_score(y_test, y_pred)  # R-squared
n = len(y_test)  # Number of samples in the test set
p = X_test.shape[1]  # Number of features
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)  # Adjusted R-squared

# Print the evaluation metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R2: {r2}')
print(f'Adjusted R2: {adjusted_r2}')
# Out:
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.852e+04, tolerance: 2.487e+03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.640e+04, tolerance: 2.485e+03
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# ## On Test

# %%
test =pd.read_csv("C:\\Users\\soumy\\Downloads\\ML Projects\\Industrial\\Dataset\\Test.csv")
test
# Out:
#       Unnamed: 0            TimeStamp  LaRP   LeRP    LaPF    LePF Duty  \
# 0              0  2018-01-01 02:45:00  4.04   0.00   65.15  100.00  Low
# 1              1  2018-01-01 09:45:00  0.00  19.22  100.00   20.00  Low
# 2              2  2018-01-01 11:15:00  0.00   5.66  100.00   52.55  Low
# 3              3  2018-01-01 18:15:00  0.00   8.96  100.00   40.77  Low
# 4              4  2018-01-01 18:30:00  0.00   5.46  100.00   53.02  Low
# ...          ...                  ...   ...    ...     ...     ...  ...
# 2185        2185  2018-12-31 12:45:00  0.00  13.22  100.00   24.57  Low
# 2186        2186  2018-12-31 13:30:00  0.00  13.50  100.00   23.80  Low
# 2187        2187  2018-12-31 18:15:00  0.00   5.88  100.00   49.57  Low
# 2188        2188  2018-12-31 20:00:00  0.00  20.08  100.00   20.19  Low
# 2189        2189  2018-12-31 23:00:00  4.87   0.00   62.09  100.00  Low
#
#       Emissions_Air_Quality_Metric
# 0                              109
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    2190 non-null   int64
#  1   TimeStamp                     2190 non-null   object
#  2   LaRP                          2190 non-null   float64
#  3   LeRP                          2190 non-null   float64
#  4   LaPF                          2190 non-null   float64
#  5   LePF                          2190 non-null   float64
#  6   Duty                          2190 non-null   object
#  7   Emissions_Air_Quality_Metric  2190 non-null   int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 137.0+ KB

# %%
test.columns
# Out:
# Index(['Unnamed: 0', 'TimeStamp', 'LaRP', 'LeRP', 'LaPF', 'LePF', 'Duty',
#        'Emissions_Air_Quality_Metric'],
#       dtype='object')

# %%
test=test.drop(columns=['Unnamed: 0', 'TimeStamp'])
test
# Out:
#       LaRP   LeRP    LaPF    LePF Duty  Emissions_Air_Quality_Metric
# 0     4.04   0.00   65.15  100.00  Low                           109
# 1     0.00  19.22  100.00   20.00  Low                           104
# 2     0.00   5.66  100.00   52.55  Low                           100
# 3     0.00   8.96  100.00   40.77  Low                           106
# 4     0.00   5.46  100.00   53.02  Low                           104
# ...    ...    ...     ...     ...  ...                           ...
# 2185  0.00  13.22  100.00   24.57  Low                            96
# 2186  0.00  13.50  100.00   23.80  Low                            99
# 2187  0.00   5.88  100.00   49.57  Low                           101
# 2188  0.00  20.08  100.00   20.19  Low                           105
# 2189  4.87   0.00   62.09  100.00  Low                            96
#
# [2190 rows x 6 columns]

# %%
test
# Out:
#       LaRP   LeRP    LaPF    LePF Duty  Emissions_Air_Quality_Metric
# 0     4.04   0.00   65.15  100.00  Low                           109
# 1     0.00  19.22  100.00   20.00  Low                           104
# 2     0.00   5.66  100.00   52.55  Low                           100
# 3     0.00   8.96  100.00   40.77  Low                           106
# 4     0.00   5.46  100.00   53.02  Low                           104
# ...    ...    ...     ...     ...  ...                           ...
# 2185  0.00  13.22  100.00   24.57  Low                            96
# 2186  0.00  13.50  100.00   23.80  Low                            99
# 2187  0.00   5.88  100.00   49.57  Low                           101
# 2188  0.00  20.08  100.00   20.19  Low                           105
# 2189  4.87   0.00   62.09  100.00  Low                            96
#
# [2190 rows x 6 columns]

# %%
test['Duty'] = test['Duty'].replace({'Low':0,'Average':1,'Major':2})
test
# Out:
#       LaRP   LeRP    LaPF    LePF  Duty  Emissions_Air_Quality_Metric
# 0     4.04   0.00   65.15  100.00     0                           109
# 1     0.00  19.22  100.00   20.00     0                           104
# 2     0.00   5.66  100.00   52.55     0                           100
# 3     0.00   8.96  100.00   40.77     0                           106
# 4     0.00   5.46  100.00   53.02     0                           104
# ...    ...    ...     ...     ...   ...                           ...
# 2185  0.00  13.22  100.00   24.57     0                            96
# 2186  0.00  13.50  100.00   23.80     0                            99
# 2187  0.00   5.88  100.00   49.57     0                           101
# 2188  0.00  20.08  100.00   20.19     0                           105
# 2189  4.87   0.00   62.09  100.00     0                            96
#
# [2190 rows x 6 columns]

# %%
## Adding features

# %%
test['LaPF'] = test['LaPF']  / 100
test['LaTP'] = test['LaRP'] * np.sqrt((1 - test['LaPF']**2) / test['LaPF']**2)
test['LePF'] = test['LePF']  / 100
test['LeTP'] = test['LeRP'] * np.sqrt((1 - test['LePF']**2) / test['LePF']**2)
test['LaAP'] = test['LaTP']/test['LaPF']
test['LeAP'] = test['LeTP']/test['LePF']
# Out:
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\soumy\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
test
# Out:
#       LaRP   LeRP    LaPF    LePF  Duty  Emissions_Air_Quality_Metric  \
# 0     4.04   0.00  0.6515  1.0000     0                           109
# 1     0.00  19.22  1.0000  0.2000     0                           104
# 2     0.00   5.66  1.0000  0.5255     0                           100
# 3     0.00   8.96  1.0000  0.4077     0                           106
# 4     0.00   5.46  1.0000  0.5302     0                           104
# ...    ...    ...     ...     ...   ...                           ...
# 2185  0.00  13.22  1.0000  0.2457     0                            96
# 2186  0.00  13.50  1.0000  0.2380     0                            99
# 2187  0.00   5.88  1.0000  0.4957     0                           101
# 2188  0.00  20.08  1.0000  0.2019     0                           105
# 2189  4.87   0.00  0.6209  1.0000     0                            96
#
#           LaTP       LeTP      LaAP        LeAP
# 0     4.704437   0.000000  7.220931    0.000000
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   LaRP                          2190 non-null   float64
#  1   LeRP                          2190 non-null   float64
#  2   LaPF                          2190 non-null   float64
#  3   LePF                          2190 non-null   float64
#  4   Duty                          2190 non-null   int64
#  5   Emissions_Air_Quality_Metric  2190 non-null   int64
#  6   LaTP                          2188 non-null   float64
#  7   LeTP                          2187 non-null   float64
#  8   LaAP                          2188 non-null   float64
#  9   LeAP                          2187 non-null   float64
# dtypes: float64(8), int64(2)
# memory usage: 171.2 KB

# %%
sns.kdeplot(test['LaTP'].dropna())
sns.kdeplot(test['LaTP'].fillna(test['LaTP'].mean()),color = 'red')
# Out:
# <Axes: xlabel='LaTP', ylabel='Density'>

# %%
test['LaTP'] = test['LaTP'].fillna(test['LaTP'].mean())
test['LeTP'] = test['LaTP'].fillna(test['LeTP'].mean())
test['LaAP'] = test['LaAP'].fillna(test['LaAP'].mean())
test['LeAP'] = test['LaAP'].fillna(test['LeAP'].mean())

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   LaRP                          2190 non-null   float64
#  1   LeRP                          2190 non-null   float64
#  2   LaPF                          2190 non-null   float64
#  3   LePF                          2190 non-null   float64
#  4   Duty                          2190 non-null   int64
#  5   Emissions_Air_Quality_Metric  2190 non-null   int64
#  6   LaTP                          2190 non-null   float64
#  7   LeTP                          2190 non-null   float64
#  8   LaAP                          2190 non-null   float64
#  9   LeAP                          2190 non-null   float64
# dtypes: float64(8), int64(2)
# memory usage: 171.2 KB

# %%
X_train
# Out:
#         LaRP   LeRP    LaPF    LePF  Duty  Emissions_Air_Quality_Metric  \
# 2284   62.52   0.00  0.7944  1.0000     0                           364
# 6299    4.60   0.00  0.6381  1.0000     0                           103
# 14656  24.06   0.00  0.9571  1.0000     1                           364
# 17880  29.87   0.00  0.8968  1.0000     2                           298
# 30787   3.47   0.00  0.7347  1.0000     0                           100
# ...      ...    ...     ...     ...   ...                           ...
# 25731   0.00  17.51  1.0000  0.2014     1                            98
# 15790  38.04   0.00  0.9212  1.0000     2                           364
# 30517   2.92   0.00  0.7641  1.0000     0                           102
# 919     4.47   0.00  0.7157  1.0000     0                           107
# 4517    4.93   0.00  0.7576  1.0000     0                            94
#
#             LaTP       LeTP       LaAP        LeAP
# 2284   47.802534   0.000000  60.174388    0.000000
# ...

# %%
test
# Out:
#       LaRP   LeRP    LaPF    LePF  Duty  Emissions_Air_Quality_Metric  \
# 0     4.04   0.00  0.6515  1.0000     0                           109
# 1     0.00  19.22  1.0000  0.2000     0                           104
# 2     0.00   5.66  1.0000  0.5255     0                           100
# 3     0.00   8.96  1.0000  0.4077     0                           106
# 4     0.00   5.46  1.0000  0.5302     0                           104
# ...    ...    ...     ...     ...   ...                           ...
# 2185  0.00  13.22  1.0000  0.2457     0                            96
# 2186  0.00  13.50  1.0000  0.2380     0                            99
# 2187  0.00   5.88  1.0000  0.4957     0                           101
# 2188  0.00  20.08  1.0000  0.2019     0                           105
# 2189  4.87   0.00  0.6209  1.0000     0                            96
#
#           LaTP      LeTP      LaAP      LeAP
# 0     4.704437  4.704437  7.220931  7.220931
# ...

# %%
df
# Out:
#        Energy_Consumption  LaRP  LeRP    LaPF    LePF  Duty  \
# 0                    3.21  2.96  0.00  0.7321  1.0000     0
# 1                    3.95  4.46  0.00  0.6678  1.0000     0
# 2                    3.23  3.28  0.00  0.7027  1.0000     0
# 3                    3.33  3.56  0.00  0.6810  1.0000     0
# 4                    3.79  4.49  0.00  0.6472  1.0000     0
# ...                   ...   ...   ...     ...     ...   ...
# 32845                3.84  4.56  0.00  0.6437  1.0000     0
# 32846                3.81  3.76  0.00  0.7071  1.0000     0
# 32847                3.82  3.16  0.07  0.7664  0.9999     0
# 32848                3.85  3.07  0.13  0.7772  0.9996     0
# 32849                3.65  3.03  0.08  0.7723  0.9999     0
#
#        Emissions_Air_Quality_Metric      LaTP      LeTP      LaAP      LeAP
# 0                               105  2.754192  0.000000  3.762043  0.000000
# 1                               101  4.971189  0.000000  7.444128  0.000000
# ...

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
# Initialize the classifier
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the classifier
rf_regressor.fit(df.drop(columns='Energy_Consumption'),df['Energy_Consumption'])

# Make predictions
y_pred = rf_regressor.predict(test)

# %%
y_pred
# Out:
# array([3.4719, 4.1074, 3.6116, ..., 3.6083, 4.3246, 3.8159])

# %%
predictions_df = pd.DataFrame(y_pred,columns=['Energy_Consumption'])

# %%
predictions_df
# Out:
#       Energy_Consumption
# 0                 3.4719
# 1                 4.1074
# 2                 3.6116
# 3                 4.1252
# 4                 3.7207
# ...                  ...
# 2185              3.4985
# 2186              3.3624
# 2187              3.6083
# 2188              4.3246
# 2189              3.8159
#
# [2190 rows x 1 columns]

# %%
predictions_df.to_csv('Energy_Consumption.csv',index=False)
